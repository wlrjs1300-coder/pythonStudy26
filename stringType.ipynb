# %%
# 문자열(string) 자료형
# 연속된 문자들을 나열한다.
# 큰따옴표, 작은따옴표 안에 작성된 모든 근자를 문자열로 취급한다.
# 따옴표로 만든 값은 직접 계산하면 안된다.

kor = "100"
mat = "100"
eng = "100"

total = kor + mat + eng
print(total)
# Out:
# 100100100

# %%
head = "Python"
tail = " is fun!"
head + tail
# Out:
# 'Python is fun!'

# %%
a = "Python"
a * 2
# Out:
# 'PythonPython'

# %%
a = "Life is too short"
len(a)
# Out:
# 17

# %%
a = "Life is too short, You need Python"
a[-2]
# Out:
# 'o'

# %%
a = "Life is too short, You need Python"
b = a[0] + a[1] + a[2] + a[3]
b
# Out:
# 'Life'

# %%
a = "Life is too short, You need Python"
a[0:17]
# Out:
# 'Life is too short'

# %%
a = "Life is too short, You need Python"
a[:]
# Out:
# 'Life is too short, You need Python'

# %%
a = "20230331Rainy"
date = a[:8]
weather = a[8:]
weather
# Out:
# 'Rainy'

# %%
a = "Pithon"
a[:1] + 'y' + a[2:]
# Out:
# 'Python'

# %%
"i eat %d apples." %3
# Out:
# 'i eat 3 apples.'

# %%
number = 3
"I eat %d apples." %number
# Out:
# 'I eat 3 apples.'

# %%
number = 10
day = "three"
"I ate %d apples. so I was sick for %s days." %(number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
"Error is %d%%" %98
# Out:
# 'Error is 98%'

# %%
"%10s"%"hi"
# Out:
# '        hi'

# %%
"%-10sjane."%'hi'
# Out:
# 'hi        jane.'

# %%
"%0.6f"%3.42134234
# Out:
# '3.421342'

# %%
"I eat {0} apples".format(3
                          )
# Out:
# 'I eat 3 apples'

# %%
"{0:^10}".format("hi")
# Out:
# '    hi    '

# %%
"{0:*^10}".format("hi")
# Out:
# '****hi****'

# %%
"{0:~<20}".format("hi")
# Out:
# 'hi~~~~~~~~~~~~~~~~~~'

# %%
d = {'name':'홍길동', 'age':30}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
f"난 {1500000:,}원이 필요해"
# Out:
# '난 1,500,000원이 필요해'

# %%
a = "hobby"
a.count('y')
# Out:
# 1

# %%
a = "Python is the best choice"
a.find('k')
# Out:
# -1

# %%
"!".join('abcd')
# Out:
# 'a!b!c!d'

# %%
a = "hi"
a.upper()
# Out:
# 'HI'

# %%
b = "Life is too short"
b.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %%
# 문자열은 더하기 식이 진행되면 글자를 붙인다.
a = "Hello World"
print(a)
# Out:
# Hello World

# %%
b = 'python is fun'
print(b)
# Out:
# python is fun

# %%
c = """Life is too short, You need Python"""
print(c)
# Out:
# Life is too short, You need Python

# %%
menu = "환영합니다. 'mbc' 아카데미 성적처리 프로그램입니다."
submenu = "1.학생등록 2.성적처리 3.성적보기 4.종료"
print(menu)
print(submenu)
# Out:
# 환영합니다. 'mbc' 아카데미 성적처리 프로그램입니다.
# 1.학생등록 2.성적처리 3.성적보기 4.종료

# %%
menu = """
==========================================
환영합니다. 'mbc' 아카데미 성적처리 프로그램입니다.
==========================================
1. 학생등록
2. 성적처리
3. 성적보기
4. 종료
>>>
"""
print(menu)
# Out:
# ...
# 환영합니다. 'mbc' 아카데미 성적처리 프로그램입니다.
# ...
# 1. 학생등록
# 2. 성적처리
# 3. 성적보기
# 4. 종료
# >>>

# %%
submenu1 = '''
=======================
학생메뉴로 진입하셨습니다.
=======================
1. 학생 전체보기
2. 학생 자세히보기
3. 학생 수정하기
4. 학생 삭제하기
5. 상위메뉴로 진입
>>>
'''
print(submenu1)
# Out:
# ...
# 학생메뉴로 진입하셨습니다.
# ...
# 1. 학생 전체보기
# 2. 학생 자세히보기
# 3. 학생 수정하기
# 4. 학생 삭제하기
# 5. 상위메뉴로 진입
# >>>

# %%
# 프로그램을 만들 때 중요한 4가지
# Create (생성), Read(읽기), Update(수정), Delete(삭제)

# %%
submenu2 = "==========================\n 성적처리메뉴로 진입하셨습니다, \n 1.학생성적등록 \n 2.학생전체성적보기 \n 3.학생개인성적보기 \n 4.학생성적수정 \n 5.학생자료백업 \n 6.상위메뉴 \n =========================="
print(submenu2)
# Out:
# ...
#  성적처리메뉴로 진입하셨습니다,
#  1.학생성적등록
#  2.학생전체성적보기
#  3.학생개인성적보기
#  4.학생성적수정
#  5.학생자료백업
#  6.상위메뉴
# ...

# %%
# Menu3.py 파일을 생성하고 print안쪽에 "="*15 하면
# =이 15번 반복하는 것을 볼 수 있다.

# %%
# 문자열의 길이를 구하는 leg()함수가 있다.
# 입력된 주민번호 글자수를 알아낸느 코드
# id/pw에 대한 글자수 검증용으로 활용할 수 있다.

inputSsn = "120604-2345678"
type(inputSsn)
# Out:
# str

# %%
len(inputSsn)
# Out:
# 14

# %%
if len(inputSsn)==14 :
    print("주민번호 14글자가 잘 입력 되었습니다.") # 참 True
else:
    print("주민번호 14글자가 잘못 입력 되었습니다.") # 거짓 False
# Out:
# 주민번호 14글자가 잘 입력 되었습니다.

# %%
# 문자열 인덱싱은 문자를 표로 만들어 0번부터 주소를 넣은 값
# 문자열 슬라이싱은 문자를 인덱스로 잘라 가져옴
word = "Life is too short, You need Python"
#       0123456789                      33

# %%
word[3] # word변수에 3번째 문자열
# Out:
# 'e'

# %%
word[-1] # 인데스에 -값은 뒤에서부터 ~
# Out:
# 'n'

# %%
b = word[0] + word[9] + 'v' + word[3]
print(b)
# Out:
# Love

# %%
# 변수[시작:-1끝] 끝번호는 해당문자를 포함하지 않음.
# word[o:3] -> 0 <= a < 3
word[0:3] #0부터 3이전까지
# Out:
# 'Lif'

# %%
# 주민번호 앞 2자리를 생년으로 추출 uear
# 주민번호 3~4 자리를 생월로 추출 month
# 주민번호 5~6 자리를 생일로 추출 day
# 주민번호 8번째 1자리를 남여 추출 sex
word1 = "260105-1234567"
word1[0:2] # year
# Out:
# '26'

# %%
word1[2:4] # month
# Out:
# '01'

# %%
word1[4:6] # day
# Out:
# '05'

# %%
if word1[7]== "1":
    print("남자")
else:
    print("여자")
# Out:
# 남자

# %%
word = "260105-1234567"

# %%
year = word[0:2]
month = word[2:4]
day = word[4:6]
print("귀하의 생년은 " + year + "년,")
print("귀하의 생월은 " + month + "월,")
print("귀하의 생일은 " + day + "일이며,")
if word[7]=="1":
    print("귀하는 남자입니다.")
else:
    print("귀하는 여자입니다.")

# 주민번호를 이용해서 남여 구분을 위한 코드
# 문자열로 인식된 숫자를 숫자로 계산하려면 타입변환 필요
# Out:
# 귀하의 생년은 26년,
# 귀하의 생월은 01월,
# 귀하의 생일은 05일이며,
# 귀하는 남자입니다.

# %%
ssnNumber = word[7]
# print(ssnNumber)
# type(ssnNumber)
ssnNumber = int(ssnNumber) # 문자가 숫자로 타입변화 됨
# type(ssnNumber)

if ssnNumber % 2 == 1 : # 숫자로된 성별을 2로 나눈 나머지가 1인지
    sex = "남자"
else:
    sex = "여자"
print(sex)
# Out:
# 남자

# %%
# 미션 주민번호 8번째 글자가 1,2,5,6 이면 1900년생
# 3,4,7,8 이면 2000년생으로 만들어보자

birth = "260105-1234567"
num = birth[7]
if num == "1":
    yearif = "19"+year
elif num == "2":
    yearif = "19"+year
elif num == "5":
    yearif = "19"+year
elif num == "6":
    yearif = "19"+year
elif num == "9":
    print("당신은 외계인입니다. 돌아가세요!")
else:
    yearif = "20"+year
print(yearif)
# Out:
# 19201926
